# %%
import pandas as pd
import numpy as np
import glob
import os

import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform, conditional
# Out:
# Using TensorFlow backend.

# %%
def delete_pycache():

    file_list = glob.glob('__pycache__/*.pyc')
    if file_list:
        for file in file_list:
            os.remove(file)
            print('deleted model %s' % file)
    else:    
        print('no model found')

# %%
delete_pycache()
# Out:
# no model found

# %%
def data():
    Xy_all = pd.read_csv('../datasets/california_housing.csv')
    X_all = Xy_all.drop(columns='HouseValue')
    y_all = Xy_all['HouseValue']
    del Xy_all
    
    XX_train, XX_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.15, random_state=42)
    
    scaler = StandardScaler()
    X_train = pd.DataFrame(scaler.fit_transform(XX_train), columns=XX_train.columns)
    X_test = pd.DataFrame(scaler.fit_transform(XX_test), columns=XX_test.columns)
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# ### How many neurons?

# %%
def model_a(X_train, y_train, X_test, y_test):

    model = Sequential()
    model.add(Dense({{choice([5, 8, 11])}}, input_dim=8, activation='relu', name='num_neurons'))      
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    
    result = model.fit(X_train, y_train, epochs=3, validation_split=0.15)

    validation_mse = np.amin(result.history['val_mean_squared_error']) 

    print('Best validation mse of epoch:', validation_mse)
    
    return {'loss': validation_mse, 'status': STATUS_OK, 'model': model}

# %%
best_run_a, best_model_a = optim.minimize(model=model_a,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=5,
                                          trials=Trials(),
                                          notebook_name='hyperas_keras')

print()
print("Best performing model chosen hyper-parameters:")
print(best_run_a)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import glob
# except:
#     pass
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from sklearn.datasets import fetch_california_housing
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import StandardScaler
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Activation, Dropout
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, conditional
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dense': hp.choice('Dense', [5, 8, 11]),
#     }
#
# >>> Data
#   1:
#   2: Xy_all = pd.read_csv('../datasets/california_housing.csv')
#   3: X_all = Xy_all.drop(columns='HouseValue')
#   4: y_all = Xy_all['HouseValue']
#   5: del Xy_all
#   6:
#   7: XX_train, XX_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.15, random_state=42)
#   8:
#   9: scaler = StandardScaler()
#  10: X_train = pd.DataFrame(scaler.fit_transform(XX_train), columns=XX_train.columns)
#  11: X_test = pd.DataFrame(scaler.fit_transform(XX_test), columns=XX_test.columns)
#  12:
#  13:
#  14:
#  15:
# >>> Resulting replaced keras model:
#
#   1: def keras_fmin_fnct(space):
#   2:
#   3:
#   4:     model = Sequential()
#   5:     model.add(Dense(space['Dense'], input_dim=8, activation='relu', name='num_neurons'))
#   6:     model.add(Dense(1))
#   7:     model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
#   8:
#   9:     result = model.fit(X_train, y_train, epochs=3, validation_split=0.15)
#  10:
#  11:     validation_mse = np.amin(result.history['val_mean_squared_error'])
#  12:
#  13:     print('Best validation mse of epoch:', validation_mse)
#  14:
#  15:     return {'loss': validation_mse, 'status': STATUS_OK, 'model': model}
#  16:
# Train on 14912 samples, validate on 2632 samples
# Epoch 1/3
# 14912/14912 [==============================] - 0s 32us/step - loss: 3.7328 - mean_squared_error: 3.7328 - val_loss: 1.2791 - val_mean_squared_error: 1.2791
# Epoch 2/3
# 14912/14912 [==============================] - 0s 23us/step - loss: 0.9287 - mean_squared_error: 0.9287 - val_loss: 0.8055 - val_mean_squared_error: 0.8055
# Epoch 3/3
# 14912/14912 [==============================] - 0s 23us/step - loss: 0.6938 - mean_squared_error: 0.6938 - val_loss: 0.6640 - val_mean_squared_error: 0.6640
# Best validation mse of epoch: 0.6639684934203023
# Train on 14912 samples, validate on 2632 samples
# Epoch 1/3
# 14912/14912 [==============================] - 1s 34us/step - loss: 2.2237 - mean_squared_error: 2.2237 - val_loss: 0.8536 - val_mean_squared_error: 0.8536
# Epoch 2/3
# 14912/14912 [==============================] - 0s 23us/step - loss: 0.7501 - mean_squared_error: 0.7501 - val_loss: 0.6141 - val_mean_squared_error: 0.6141
# Epoch 3/3
# 14912/14912 [==============================] - 0s 23us/step - loss: 0.6016 - mean_squared_error: 0.6016 - val_loss: 0.5363 - val_mean_squared_error: 0.5363
# Best validation mse of epoch: 0.536301168355536
# Train on 14912 samples, validate on 2632 samples
# Epoch 1/3
# 14912/14912 [==============================] - 1s 40us/step - loss: 1.6873 - mean_squared_error: 1.6873 - val_loss: 1.0469 - val_mean_squared_error: 1.0469
# Epoch 2/3
# 14912/14912 [==============================] - 0s 21us/step - loss: 0.8939 - mean_squared_error: 0.8939 - val_loss: 0.7836 - val_mean_squared_error: 0.7836
# Epoch 3/3
# 14912/14912 [==============================] - 0s 22us/step - loss: 0.6866 - mean_squared_error: 0.6866 - val_loss: 0.6300 - val_mean_squared_error: 0.6300
# Best validation mse of epoch: 0.629987522461494
# Train on 14912 samples, validate on 2632 samples
# Epoch 1/3
# 14912/14912 [==============================] - 1s 35us/step - loss: 2.0708 - mean_squared_error: 2.0708 - val_loss: 0.8059 - val_mean_squared_error: 0.8059
# Epoch 2/3
# 14912/14912 [==============================] - 0s 22us/step - loss: 0.7039 - mean_squared_error: 0.7039 - val_loss: 0.6016 - val_mean_squared_error: 0.6016
# Epoch 3/3
# 14912/14912 [==============================] - 0s 22us/step - loss: 0.5405 - mean_squared_error: 0.5405 - val_loss: 0.5084 - val_mean_squared_error: 0.5084
# Best validation mse of epoch: 0.508378000109029
# Train on 14912 samples, validate on 2632 samples
# Epoch 1/3
# 14912/14912 [==============================] - 1s 41us/step - loss: 1.5630 - mean_squared_error: 1.5630 - val_loss: 0.8933 - val_mean_squared_error: 0.8933
# Epoch 2/3
# 14912/14912 [==============================] - 0s 25us/step - loss: 0.7599 - mean_squared_error: 0.7599 - val_loss: 0.5936 - val_mean_squared_error: 0.5936
# Epoch 3/3
# 14912/14912 [==============================] - 0s 22us/step - loss: 0.5444 - mean_squared_error: 0.5444 - val_loss: 0.4923 - val_mean_squared_error: 0.4923
# Best validation mse of epoch: 0.4922883894668162
#
# Best performing model chosen hyper-parameters:
# {'Dense': 0}

# %% [markdown]
# ### Which activation function?

# %%
def model_b(X_train, y_train, X_test, y_test):

    model = Sequential()
    model.add(Dense(8, input_dim=8, name='num_neurons'))
    model.add(Activation({{choice(['relu', 'sigmoid'])}}))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    
    result = model.fit(X_train, y_train, epochs=3, validation_split=0.15)

    validation_mse = np.amin(result.history['val_mean_squared_error']) 

    print('Best validation mse of epoch:', validation_mse)
    
    return {'loss': validation_mse, 'status': STATUS_OK, 'model': model}

# %%
best_run_b, best_model_b = optim.minimize(model=model_b,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=5,
                                      trials=Trials(),
                                      notebook_name='hyperas_keras')

print()
print("Best performing model chosen hyper-parameters:")
print(best_run_b)

# %% [markdown]
# ### Should there be an additional layer?

# %%
def model_c(X_train, y_train, X_test, y_test):

    model = Sequential()
    model.add(Dense({{choice([8,8])}}, input_dim=8, activation='relu', name='num_neurons'))  
    
    if conditional({{choice(['one', 'two'])}}) == 'two':
        model.add(Dense(8, activation='relu', name='optional_dense'))
    
    model.add(Dense(1, activation='relu'))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    
    result = model.fit(X_train, y_train, 
                       batch_size={{choice([64, 128])}}, 
                       epochs=3, 
                       validation_split=0.15)

    validation_mse = np.amin(result.history['val_mean_squared_error']) 

    print('Best validation mse of epoch:', validation_mse)
    
    return {'loss': validation_mse, 'status': STATUS_OK, 'model': model}

# %%
best_run_c, best_model_c = optim.minimize(model=model_c,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=5,
                                      trials=Trials(),
                                      notebook_name='hyperas_keras')

print()
print("Best performing model chosen hyper-parameters:")
print(best_run_c)

# %% [markdown]
# ### Which dropout should I use?

# %%
def model_d(X_train, y_train, X_test, y_test):

    model = Sequential()
    model.add(Dense(8, input_dim=8, activation='relu', name='num_neurons'))   
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    
    result = model.fit(X_train, y_train, epochs=3, validation_split=0.15)

    validation_mse = np.amin(result.history['val_mean_squared_error']) 

    print('Best validation mse of epoch:', validation_mse)
    
    return {'loss': validation_mse, 'status': STATUS_OK, 'model': model}

# %%
best_run_d, best_model_d = optim.minimize(model=model_d,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=5,
                                      trials=Trials(),
                                      notebook_name='hyperas_keras')

print()
print("Best performing model chosen hyper-parameters:")
print(best_run_d)

# %% [markdown]
# ### Hyperparameter Optimization

# %%
def model_e(X_train, y_train, X_test, y_test):

    model = Sequential()
    model.add(Dense({{choice([4, 8, 12])}}, input_dim=8))
    model.add(Activation({{choice(['relu', 'sigmoid'])}}))
    model.add(Dropout({{uniform(0, 1)}}))
    
    if conditional({{choice(['one', 'two'])}}) == 'two':
        model.add(Dense({{choice([4, 8])}}))
        model.add(Activation({{choice(['relu', 'sigmoid'])}}))
        model.add(Dropout({{uniform(0, 1)}}))
    
    model.add(Dense(1))
    model.compile(loss='mean_squared_error',
                  optimizer={{choice(['rmsprop', 'adam'])}},
                  metrics=['mean_squared_error'])
    
    result = model.fit(X_train, y_train, 
                       batch_size={{choice([32, 64])}}, 
                       epochs=50, 
                       validation_split=0.15)

    validation_mse = np.amin(result.history['val_mean_squared_error']) 

    print('Best validation mse of epoch:', validation_mse)
    
    return {'loss': validation_mse, 'status': STATUS_OK, 'model': model}

# %%
best_run_e, best_model_e = optim.minimize(model=model_e,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=2,
                                          trials=Trials(),
                                          notebook_name='hyperas_keras')

print()
print("Best performing model chosen hyper-parameters:")
print(best_run_e)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import glob
# except:
#     pass
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from sklearn.datasets import fetch_california_housing
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import StandardScaler
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Activation, Dropout
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, conditional
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dense': hp.choice('Dense', [4, 8, 12]),
#         'Activation': hp.choice('Activation', ['relu', 'sigmoid']),
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'conditional': hp.choice('conditional', ['one', 'two']),
#         'Dense_1': hp.choice('Dense_1', [4, 8]),
#         'Activation_1': hp.choice('Activation_1', ['relu', 'sigmoid']),
#         'Dropout_1': hp.uniform('Dropout_1', 0, 1),
#         'optimizer': hp.choice('optimizer', ['rmsprop', 'adam']),
#         'batch_size': hp.choice('batch_size', [32, 64]),
#     }
#
# >>> Data
#   1:
#   2: Xy_all = pd.read_csv('../datasets/california_housing.csv')
#   3: X_all = Xy_all.drop(columns='HouseValue')
#   4: y_all = Xy_all['HouseValue']
#   5: del Xy_all
#   6:
#   7: XX_train, XX_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.15, random_state=42)
#   8:
#   9: scaler = StandardScaler()
#  10: X_train = pd.DataFrame(scaler.fit_transform(XX_train), columns=XX_train.columns)
#  11: X_test = pd.DataFrame(scaler.fit_transform(XX_test), columns=XX_test.columns)
#  12:
#  13:
#  14:
#  15:
# >>> Resulting replaced keras model:
#
#   1: def keras_fmin_fnct(space):
#   2:
#   3:
#   4:     model = Sequential()
#   5:     model.add(Dense(space['Dense'], input_dim=8))
#   6:     model.add(Activation(space['Activation']))
#   7:     model.add(Dropout(space['Dropout']))
#   8:
#   9:     if conditional(space['conditional']) == 'two':
#  10:         model.add(Dense(space['Dense_1']))
#  11:         model.add(Activation(space['Activation_1']))
#  12:         model.add(Dropout(space['Dropout_1']))
#  13:
#  14:     model.add(Dense(1))
#  15:     model.compile(loss='mean_squared_error',
#  16:                   optimizer=space['optimizer'],
#  17:                   metrics=['mean_squared_error'])
#  18:
#  19:     result = model.fit(X_train, y_train,
#  20:                        batch_size=space['batch_size'],
#  21:                        epochs=50,
#  22:                        validation_split=0.15)
#  23:
#  24:     validation_mse = np.amin(result.history['val_mean_squared_error'])
#  25:
#  26:     print('Best validation mse of epoch:', validation_mse)
#  27:
#  28:     return {'loss': validation_mse, 'status': STATUS_OK, 'model': model}
#  29:
# Train on 14912 samples, validate on 2632 samples
# Epoch 1/50
# 14912/14912 [==============================] - 1s 40us/step - loss: 4.4818 - mean_squared_error: 4.4818 - val_loss: 1.7909 - val_mean_squared_error: 1.7909
# Epoch 2/50
# 14912/14912 [==============================] - 0s 25us/step - loss: 1.9632 - mean_squared_error: 1.9632 - val_loss: 1.1645 - val_mean_squared_error: 1.1645
# Epoch 3/50
# 14912/14912 [==============================] - 0s 27us/step - loss: 1.6429 - mean_squared_error: 1.6429 - val_loss: 0.9575 - val_mean_squared_error: 0.9575
# Epoch 4/50
# 14912/14912 [==============================] - 0s 26us/step - loss: 1.2145 - mean_squared_error: 1.2145 - val_loss: 0.8571 - val_mean_squared_error: 0.8571
# Epoch 5/50
# 14912/14912 [==============================] - 0s 27us/step - loss: 1.1560 - mean_squared_error: 1.1560 - val_loss: 0.8083 - val_mean_squared_error: 0.8083
# Epoch 6/50
# 14912/14912 [==============================] - 0s 27us/step - loss: 1.0870 - mean_squared_error: 1.0870 - val_loss: 0.8333 - val_mean_squared_error: 0.8333
# Epoch 7/50
# 14912/14912 [==============================] - 0s 27us/step - loss: 1.0493 - mean_squared_error: 1.0493 - val_loss: 0.7824 - val_mean_squared_error: 0.7824
# Epoch 8/50
# 14912/14912 [==============================] - 0s 28us/step - loss: 1.0300 - mean_squared_error: 1.0300 - val_loss: 0.7720 - val_mean_squared_error: 0.7720
# Epoch 9/50
# 14912/14912 [==============================] - 0s 25us/step - loss: 1.2276 - mean_squared_error: 1.2276 - val_loss: 0.7732 - val_mean_squared_error: 0.7732
# Epoch 10/50
# 14912/14912 [==============================] - 0s 27us/step - loss: 1.0206 - mean_squared_error: 1.0206 - val_loss: 0.7959 - val_mean_squared_error: 0.7959
# Epoch 11/50
# 14912/14912 [==============================] - 0s 28us/step - loss: 1.0454 - mean_squared_error: 1.0454 - val_loss: 0.8063 - val_mean_squared_error: 0.8063
# Epoch 12/50
# 14912/14912 [==============================] - 0s 28us/step - loss: 1.0414 - mean_squared_error: 1.0414 - val_loss: 0.7644 - val_mean_squared_error: 0.7644
# Epoch 13/50
# 14912/14912 [==============================] - 0s 28us/step - loss: 1.1002 - mean_squared_error: 1.1002 - val_loss: 0.7708 - val_mean_squared_error: 0.7708
# Epoch 14/50
# 14912/14912 [==============================] - 0s 27us/step - loss: 1.3042 - mean_squared_error: 1.3042 - val_loss: 0.7884 - val_mean_squared_error: 0.7884
# Epoch 15/50
# 14912/14912 [==============================] - 0s 27us/step - loss: 1.0806 - mean_squared_error: 1.0806 - val_loss: 0.7897 - val_mean_squared_error: 0.7897
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5598 - mean_squared_error: 0.5598 - val_loss: 0.4569 - val_mean_squared_error: 0.4569
# Epoch 36/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5531 - mean_squared_error: 0.5531 - val_loss: 0.4537 - val_mean_squared_error: 0.4537
# Epoch 37/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5582 - mean_squared_error: 0.5582 - val_loss: 0.4543 - val_mean_squared_error: 0.4543
# Epoch 38/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5485 - mean_squared_error: 0.5485 - val_loss: 0.4523 - val_mean_squared_error: 0.4523
# Epoch 39/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5572 - mean_squared_error: 0.5572 - val_loss: 0.4504 - val_mean_squared_error: 0.4504
# Epoch 40/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5486 - mean_squared_error: 0.5486 - val_loss: 0.4494 - val_mean_squared_error: 0.4494
# Epoch 41/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5450 - mean_squared_error: 0.5450 - val_loss: 0.4488 - val_mean_squared_error: 0.4488
# Epoch 42/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5421 - mean_squared_error: 0.5421 - val_loss: 0.4496 - val_mean_squared_error: 0.4496
# Epoch 43/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5493 - mean_squared_error: 0.5493 - val_loss: 0.4518 - val_mean_squared_error: 0.4518
# Epoch 44/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5439 - mean_squared_error: 0.5439 - val_loss: 0.4481 - val_mean_squared_error: 0.4481
# Epoch 45/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5479 - mean_squared_error: 0.5479 - val_loss: 0.4457 - val_mean_squared_error: 0.4457
# Epoch 46/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5454 - mean_squared_error: 0.5454 - val_loss: 0.4467 - val_mean_squared_error: 0.4467
# Epoch 47/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5352 - mean_squared_error: 0.5352 - val_loss: 0.4459 - val_mean_squared_error: 0.4459
# Epoch 48/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5468 - mean_squared_error: 0.5468 - val_loss: 0.4464 - val_mean_squared_error: 0.4464
# Epoch 49/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5322 - mean_squared_error: 0.5322 - val_loss: 0.4450 - val_mean_squared_error: 0.4450
# Epoch 50/50
# 14912/14912 [==============================] - 0s 11us/step - loss: 0.5390 - mean_squared_error: 0.5390 - val_loss: 0.4451 - val_mean_squared_error: 0.4451
# Best validation mse of epoch: 0.44504431968039654
#
# Best performing model chosen hyper-parameters:
# {'Activation': 1, 'Activation_1': 1, 'Dense': 2, 'Dense_1': 0, 'Dropout': 0.5152808649614491, 'Dropout_1': 0.42522861686845626, 'batch_size': 1, 'conditional': 0, 'optimizer': 0}
