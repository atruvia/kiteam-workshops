# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_train = pd.read_csv('all/train_V2.csv')

# %%
df_train.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace      ...       revives  \
# 0         0.00      0              0      0         60      ...             0
# 1        91.47      0              0      0         57      ...             0
# 2        68.00      0              0      0         47      ...             0
# 3        32.90      0              0      0         75      ...             0
# 4       100.00      0              0      0         45      ...             0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# ...

# %%
df_train.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06   4.446966e+06
# mean   2.338149e-01  1.106908e+00  1.307171e+02  6.578755e-01   2.268196e-01
# std    5.885731e-01  1.715794e+00  1.707806e+02  1.145743e+00   6.021553e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.424000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.860000e+02  1.000000e+00   0.000000e+00
# max    2.200000e+01  3.300000e+01  6.616000e+03  5.300000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06
# mean   1.370147e+00  4.759935e+01  5.050060e+02  9.247833e-01  5.439551e-01
# ...

# %% [markdown]
# ## Explore Variables

# %% [markdown]
# ### Bar Plots

# %%
f, ax = plt.subplots(figsize=(15, 6))
df_train['kills'].value_counts().sort_values(ascending=False).plot.bar()
plt.show()

# %% [markdown]
# ### Histplots

# %%
f, ax = plt.subplots(figsize=(15, 6))
sns.distplot(df_train['damageDealt'])
plt.show()
# Out:
# /Users/marcel/anaconda3/envs/ML_Setup/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %% [markdown]
# ### Id / Group Id / Match Id

# %%
f, ax = plt.subplots(figsize=(15, 6))
df_train[df_train['matchId']=='a10357fd1a4a91']['groupId'].value_counts().sort_values(ascending=False).plot.bar()
plt.show()

# %% [markdown]
# ### MatchType

# %%
f, ax = plt.subplots(figsize=(15, 6))
df_train['matchType'].value_counts().sort_values(ascending=False).plot.bar()
plt.show()

# %%
df_train[df_train['matchType']=='solo']['revives'].value_counts().sort_values(ascending=False)
# Out:
# 0    181943
# Name: revives, dtype: int64

# %% [markdown]
# ## Look for Correlation

# %% [markdown]
# ### Correlation Matrix Top 10

# %%
k = 10
corrmat = df_train.corr() 
cols = corrmat.nlargest(k, 'winPlacePerc').index 
cm = np.corrcoef(df_train[cols].values.T) 
sns.set(font_scale=1.25)
f, ax = plt.subplots(figsize=(16, 12))
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 12}, 
                 yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
df_train.plot(x="walkDistance",y="winPlacePerc", kind="scatter", figsize = (15,12))
plt.show()

# %%
sns.jointplot(x="winPlacePerc", y="kills", data=df_train, ratio=3, color="r")
plt.show()
# Out:
# /Users/marcel/anaconda3/envs/ML_Setup/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#
# /Users/marcel/anaconda3/envs/ML_Setup/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %% [markdown]
# ## Cheaters (?)

# %%
df_train['totalDistance'] = df_train['rideDistance'] + df_train['walkDistance'] + df_train['swimDistance']
df_train['killsWithoutMoving'] = ((df_train['kills'] > 0) & (df_train['totalDistance'] == 0))

df_train[df_train['killsWithoutMoving'] == True].head(5)
# Out:
# (1535, 31)
#                    Id         groupId         matchId  assists  boosts  \
# 1824   b538d514ef2476  0eb2ce2f43f9d6  35e7d750e442e2        0       0
# 6673   6d3a61da07b7cb  2d8119b1544f87  904cecf36217df        2       0
# 11892  550398a8f33db7  c3fd0e2abab0af  db6f6d1f0d4904        2       0
# 14631  58d690ee461e9d  ea5b6630b33d67  dbf34301df5e53        0       0
# 15591  49b61fc963d632  0f5c5f19d9cc21  904cecf36217df        0       0
#
#        damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 1824         593.0      0              0      3         18
# 6673         346.6      0              0      6         33
# 11892       1750.0      0              4      5          3
# 14631        157.8      0              0      0         69
# 15591        100.0      0              1      0         37
#
#               ...          roadKills  swimDistance  teamKills  \
# 1824          ...                  0           0.0          0
# ...

# %% [markdown]
# ## Other Anomalies

# %%
plt.figure(figsize=(12,4))
sns.distplot(df_train['longestKill'], bins=10)
plt.show()
# Out:
# /Users/marcel/anaconda3/envs/ML_Setup/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
df_train[df_train['longestKill'] >= 1000].head(10)
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 202281   88e2af7d78af5a  34ddeede52c042  4346bc63bc67fa        0       3
# 240005   41c2f5c0699807  9faecf87ab4275  634edab75860b3        5       0
# 324313   ef390c152bcc3d  30fd444be3bbc1  4f7f8d6cf558b4        2       0
# 523088   1ff9763ca30279  7fb3a83ebb050d  838cb9a3c94598        0       0
# 656553   9948b058562163  c8cb8491112bf6  0104eeb664494d        6       0
# 803632   4e7e6c74e3c57d  94698690918933  da91b0c3d875f8        0       0
# 895411   1f5ba6e0cfb968  512ea24b831be3  5fb0d8b1fc16cf        4       0
# 996713   f4082eee4c45e9  4d02ce950f74fc  838cb9a3c94598        1       0
# 1172437  303a93cfa1f46c  8795d39fd0df86  9c8962b58bb3e3        2       1
# 1209416  528659ff1c1aec  7d1ba83423551d  ea9386587d5888        0       6
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 202281         783.9      5              1      1          5
# ...

# %%
list(df_train.columns)
# Out:
# ['Id',
#  'groupId',
#  'matchId',
#  'assists',
#  'boosts',
#  'damageDealt',
#  'DBNOs',
#  'headshotKills',
#  'heals',
#  'killPlace',
#  'killPoints',
#  'kills',
#  'killStreaks',
#  'longestKill',
#  'matchDuration',
#  'matchType',
#  'maxPlace',
#  'numGroups',
#  'rankPoints',
#  'revives',
#  'rideDistance',
#  'roadKills',
#  'swimDistance',
#  'teamKills',
#  'vehicleDestroys',
#  'walkDistance',
#  'weaponsAcquired',
#  'winPoints',
#  'winPlacePerc']
